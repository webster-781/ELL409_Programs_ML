# %%
from IPython import display
import numpy as np
from matplotlib import pyplot as plt

# %%
display.Image("./Plots/Unregularised1.png")

# %% [markdown]
# Unregularised on 20 data values, alpha = 0.2575, epochs = 100000

# %%
display.Image("./Plots/Reg1.png")

# %% [markdown]
# Regularised on 20 data values, alpha = 0.2575, epochs = 100000, lamda = $10^{-3}$
#
# Weights 20:[ 6.99844853 -0.03226162  0.16500128 -0.09958065 -0.06992406  0.03479712] 9.058140821288296e-05
#
# Weights 1: [ 6.99763266 -0.03071423  0.15228903 -0.12516056 -0.07866171  0.05232118] 0.0002692292039700181

# %%
display.Image("./Plots/Reg2.png")

# %% [markdown]
# Regularised on 20 data values, alpha = 0.2575, epochs = 100000, lamda = $10^{-6}$
#
# Weights 20:
# [ 7.01245491e+00 -7.38997364e-02  2.43680579e-01 -1.47618478e-04 -4.56896422e-01  2.63693209e-01]
# 1.8362104524431487e-05
#
# Weights 1 : [ 7.0163391  -0.13882143  0.12883413  1.00536247 -1.91838905  0.85559401]
# 0.00038653431233831375

# %%
display.Image("./Plots/Reg4.png")

# %% [markdown]
# Regularised on 20 data values, alpha = 0.2575, epochs = 100000, lamda = $10^{-9}$
#
# Weights 20: [ 7.01246519e+00 -7.41457336e-02  2.43897122e-01  2.22906349e-03
#  -4.61467674e-01  2.65874523e-01] 1.827366897073458e-05
#
# Weights 1 : [ 7.01658372 -0.13398875  0.12048866  1.1556234  -2.12145651  0.9561098 ] 1.9984499746751892e-05

# %%
display.Image("./Plots/Reg3.png")

# %% [markdown]
# Regularised on 20 data values, alpha = 0.2575, epochs = 100000, lamda = $10^{-12}$
#
# Weights 20: [ 7.01246520e+00 -7.41459813e-02  2.43897338e-01  2.23146304e-03
#  -4.61472282e-01  2.65876721e-01] 1.8273580080530362e-05
#
# Weights 1 : [ 7.01789375 -0.14611076  0.11424716  1.16669453 -2.12880771  0.95873002] 1.7211510619246813e-06

# %%
values =np.array([[9.058140821288296e-05,0.0002692292039700181],
            [1.8362104524431487e-05,0.00038653431233831375],
            [1.827366897073458e-05,1.9984499746751892e-05],
            [1.8273580080530362e-05,1.7211510619246813e-06]])
values = values.T
lamdas = [1e-12,1e-9,1e-6,1e-3]
plt.figure()
plt.plot(lamdas,values[0],'green')
plt.plot(lamdas,values[1],'red')
plt.xscale('log')
plt.legend(['Batch Size 20', 'Batch Size 1'],loc = 'upper right')
plt.show()
